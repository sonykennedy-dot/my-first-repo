# %% [markdown]
# Hardware refers to the physical parts of a computer that you can see and touch, while software refers to the programs and instructions that run on the hardware. Hardware performs tasks, and software tells it how to perform them. For example, a CPU is hardware, and Windows is software.
